# %% [markdown]
# # MathSlate Playground
#
# The site already includes browser display and range-control support. Run the next cell once to install the bundled MathSlate wheel.

# %%
import piplite

await piplite.install("mathslate")

# %%
from mathslate import plot, sin, x

figure = plot(sin(x), (x, -6, 6), verbose=False)
figure
