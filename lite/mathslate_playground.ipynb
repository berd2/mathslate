# %% [markdown]
# # MathSlate Playground
#
# Run the next cell once to install MathSlate and the browser notebook display/widget support. Browser Python cannot install packages automatically.

# %%
import piplite

await piplite.install(["mathslate", "nbformat", "ipywidgets", "anywidget"])

# %%
from mathslate import plot, sin, x

figure = plot(sin(x), (x, -6, 6), verbose=False)
figure
