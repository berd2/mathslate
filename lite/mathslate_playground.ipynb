# %% [markdown]
# # MathSlate Playground
#
# Run the next cell once to install the MathSlate wheel bundled with this JupyterLite site. Browser Python cannot install it automatically.

# %%
import piplite

await piplite.install("mathslate")

# %%
from mathslate import plot, sin, x

figure = plot(sin(x), (x, -6, 6), verbose=False)
figure.plotly
